# %%
# %cd /Users/shivamkaushik/Code/ik-agent
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
from src.modules.ik_transforms.transforms.effects_and_enhancement import Effects

import os
from imagekitio import ImageKit
from IPython.display import Image, display


client = ImageKit(
    private_key=os.environ.get("IMAGEKIT_PRIVATE_KEY"),
)

def build_url(
    url_endpoint: str,
    src: str,
    transformation = None,
) -> str:
    if isinstance(transformation, dict):
        transformation = [transformation]
    url = client.helper.build_url(
        url_endpoint=url_endpoint,
        src=src,
        transformation=transformation,
    )
    # print(url)
    display(Image(url=url))
    return url
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.

# %% [markdown]
# # Contrast

# %%
params = {
    "contrast": True
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-contrast"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-contrast'

# %% [markdown]
# # Sharpen

# %%
params = {
    "sharpen": True,
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-sharpen"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-sharpen'

# %%
params = {
    "sharpen": 10,
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-sharpen-10"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-sharpen-10'

# %% [markdown]
# # Unsharp Mask

# %%
params = {
    "unsharp_mask": {
        "radius": 2,
        "sigma": 2,
        "amount": 0.8,
        "threshold": 0.024
    },
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=r-2,sigma-2,amount-0.8,threshold-0.024"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=r-2,sigma-2,amount-0.8,threshold-0.024'

# %% [markdown]
# # e-Shadow

# %%
params = {
    "shadow": True
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="lipstick_1M.png",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/lipstick_1M.png?tr=e-shadow"/>
# 'https://ik.imagekit.io/demo/lipstick_1M.png?tr=e-shadow'

# %%
params = {
    "shadow": {
        'blur': 15,
        'saturation': 40,
        'x_offset': 10,
        'y_offset': -5,
    }
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="lipstick_1M.png",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/lipstick_1M.png?tr=e-shadow-bl-15_st-40_x-10_y-N5"/>
# 'https://ik.imagekit.io/demo/lipstick_1M.png?tr=e-shadow-bl-15_st-40_x-10_y-N5'

# %% [markdown]
# # Gradient

# %%
params = {
    "gradient": True
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-gradient"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-gradient'

# %%
params = {
    "gradient": {
        'linear_direction': 45,
        'from_color': 'FF000000',
        'to_color': 'FFFFFF50',
        'stop_point': 0.5,
    }
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-gradient-ld-45_from-FF000000_to-FFFFFF50_sp-0.5"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-gradient-ld-45_from-FF000000_to-FFFFFF50_sp-0.5'

# %%
params = {
    "gradient": {
        'linear_direction': 'top',
        'from_color': 'green',
        'to_color': '00FF0010',
        'stop_point': 1,
    }
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-gradient-ld-top_from-green_to-00FF0010_sp-1"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-gradient-ld-top_from-green_to-00FF0010_sp-1'

# %% [markdown]
# # Grayscale

# %%
params = {
    "grayscale": True
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="sample_image.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/sample_image.jpg?tr=e-grayscale"/>
# 'https://ik.imagekit.io/demo/sample_image.jpg?tr=e-grayscale'

# %% [markdown]
# # Perspective transform

# %%
# e-distort-p-<x1>_<y1>_<x2>_<y2>_<x3>_<y3>_<x4>_<y4>


params = {
    "perspective_distort": {
        'x1': 100,
        'y1': 100,
        'x2': 700,
        'y2': -100,
        'x3': 600,
        'y3': 600,
        'x4': 0,
        'y4': 600,
    }
}

transforms = Effects(**params).to_transform_dicts()
build_url(
    url_endpoint=" https://ik.imagekit.io/ikmedia",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=e-distort-p-100_100_700_N100_600_600_0_600"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=e-distort-p-100_100_700_N100_600_600_0_600'

# %% [markdown]
# # Arc transform

# %%
# e-distort-p-<x1>_<y1>_<x2>_<y2>_<x3>_<y3>_<x4>_<y4>


params = {
    "arc_distort": {
        'degrees': -30,
    }
}

transforms = Effects(**params).to_transform_dicts()


build_url(
    url_endpoint=" https://ik.imagekit.io/ikmedia",
    src="/docs_images/features/image-transformations/car.jpeg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg?tr=e-distort-a-N30"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg?tr=e-distort-a-N30'

# %% [markdown]
# # Trim

# %%
params = {
    "trim": True
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="/img/trim_example_BkgQVu7oX.png",
    transformation=transforms,
)
# Out:
# [{'t': True}]
# <img src="https://ik.imagekit.io/demo/img/trim_example_BkgQVu7oX.png?tr=t-true"/>
# 'https://ik.imagekit.io/demo/img/trim_example_BkgQVu7oX.png?tr=t-true'

# %%
params = {
    "trim": 5
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="/img/trim_example_BkgQVu7oX.png",
    transformation=transforms,
)
# Out:
# [{'t': 5}]
# <img src="https://ik.imagekit.io/demo/img/trim_example_BkgQVu7oX.png?tr=t-5"/>
# 'https://ik.imagekit.io/demo/img/trim_example_BkgQVu7oX.png?tr=t-5'

# %%
params = {
    "trim": 50
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="/img/trim_example_BkgQVu7oX.png",
    transformation=transforms,
)
# Out:
# [{'t': 50}]
# <img src="https://ik.imagekit.io/demo/img/trim_example_BkgQVu7oX.png?tr=t-50"/>
# 'https://ik.imagekit.io/demo/img/trim_example_BkgQVu7oX.png?tr=t-50'

# %% [markdown]
# # Border

# %%
params = {
    "border": {
        "border_width": 20,
        "color": "FF00FF99"
    }
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'b': '20_FF00FF99'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=b-20_FF00FF99"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=b-20_FF00FF99'

# %%
params = {
    "border": {
        "border_width": 20,
        "color": "red"
    }
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'b': '20_red'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=b-20_red"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=b-20_red'

# %% [markdown]
# # Rotate

# %%
params = {
    "rotate": "auto"
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'rt': 'auto'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=rt-auto"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=rt-auto'

# %%
params = {
    "rotate": 90
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'rt': '90'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=rt-90"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=rt-90'

# %%
params = {
    "rotate": -90
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'rt': 'N90'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=rt-N90"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=rt-N90'

# %% [markdown]
# # Flip

# %%
params = {
    "flip": 'h'
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'fl': 'h'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=fl-h"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=fl-h'

# %% [markdown]
# # Radius

# %%
params = {
    "radius": 50
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'r': '50'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=r-50"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=r-50'

# %%
params = {
    "radius": "max"
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'r': 'max'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=r-max"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=r-max'

# %%
params = {
    "radius": "10_20_30_40"
}

transforms = Effects(**params).to_transform_dicts()
print(transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia/",
    src="docs_images/examples/example_food_3.jpg",
    transformation=transforms,
)
# Out:
# [{'r': '10_20_30_40'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=r-10_20_30_40"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=r-10_20_30_40'

# %% [markdown]
# # Background

# %%
params = {
    "background": "red"
}

effect_transforms = Effects(**params).to_transform_dicts()
print(effect_transforms)

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia",
    src="/docs_images/examples/example_food_3.jpg",
    transformation=effect_transforms,
)
# Out:
# [{'bg': 'red'}]
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=bg-red"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=bg-red'

# %%
params = {
    "opacity": 50
}

effect_transforms = Effects(**params).to_transform_dicts()

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia",
    src="/docs_images/examples/example_food_3.jpg",
    transformation=effect_transforms,
)
# Out:
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=o-50"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=o-50'

# %%
params = {
    "opacity": 50,
}

effect_transforms1 = Effects(**params).to_transform_dicts()

params = {
    "background": 'red',
}

effect_transforms2 = Effects(**params).to_transform_dicts()

build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia",
    src="/docs_images/examples/example_food_3.jpg",
    transformation=[*effect_transforms1, *effect_transforms2],
)
# Out:
# <img src="https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=o-50:bg-red"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=o-50:bg-red'

# %% [markdown]
# # Color Replace

# %%
params = {
    "color_replace": {
        "to_color": "00FF00",
    },
}
effect_transforms = Effects(**params).to_transform_dicts()

build_url(
    url_endpoint="https://ikmedia.imagekit.io",
    src="/docs_images/examples/example_color-replace.jpg",
    transformation=effect_transforms,
)
# Out:
# <img src="https://ikmedia.imagekit.io/docs_images/examples/example_color-replace.jpg?tr=cr-00FF00_35"/>
# 'https://ikmedia.imagekit.io/docs_images/examples/example_color-replace.jpg?tr=cr-00FF00_35'

# %%
params = {
    "color_replace": {
        "to_color": "00FF00",
        "tolerance": 40,
    },
}
effect_transforms = Effects(**params).to_transform_dicts()

build_url(
    url_endpoint="https://ikmedia.imagekit.io",
    src="/docs_images/examples/example_color-replace.jpg",
    transformation=effect_transforms,
)
# Out:
# <img src="https://ikmedia.imagekit.io/docs_images/examples/example_color-replace.jpg?tr=cr-00FF00_40"/>
# 'https://ikmedia.imagekit.io/docs_images/examples/example_color-replace.jpg?tr=cr-00FF00_40'

# %%
params = {
    "color_replace": {
        "to_color": "00FF00",
        "tolerance": 40,
        "from_color": "FF0000",
    },
}
effect_transforms = Effects(**params).to_transform_dicts()

build_url(
    url_endpoint="https://ikmedia.imagekit.io",
    src="/docs_images/examples/example_color-replace.jpg",
    transformation=effect_transforms,
)
# Out:
# <img src="https://ikmedia.imagekit.io/docs_images/examples/example_color-replace.jpg?tr=cr-FF0000_40_00FF00"/>
# 'https://ikmedia.imagekit.io/docs_images/examples/example_color-replace.jpg?tr=cr-FF0000_40_00FF00'
