# %%
# %cd /Users/shivamkaushik/Code/ik-agent
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
import os
from imagekitio import ImageKit
from IPython.display import Image, display

# %%
from src.modules.ik_transforms.transforms.image_overlay import ImageOverlay
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.

# %%
parent = ImageOverlay(
    image_path="/logo-white_SJwqB4Nfe.png", width=100, height=50, layer_x=10, layer_y=10
)
transformation = parent.to_overlay_dict()


client = ImageKit(
    private_key=os.environ.get("IMAGEKIT_PRIVATE_KEY"),
)

src = "medium_cafe_B1iTdD0C.jpg"
# URL with image overlay
url = client.helper.build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src=src,
    transformation=[transformation],
)
display(Image(url=url))
# Result: URL with image overlay positioned at x:10, y:10
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-10,ly-10,w-100,h-50,l-end"/>

# %%
parent = ImageOverlay(
    image_path="/logo-white_SJwqB4Nfe.png",
    lx=100,
    ly=100,
    # e_grayscale=True
)
transformation = parent.to_overlay_dict()


client = ImageKit(
    private_key=os.environ.get("IMAGEKIT_PRIVATE_KEY"),
)

src = "medium_cafe_B1iTdD0C.jpg"
# URL with image overlay
url = client.helper.build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src=src,
    transformation=[transformation],
)

print(url)

display(Image(url=url))
# Result: URL with image overlay positioned at x:10, y:10
# Out:
# https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,l-end
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,l-end"/>

# %%
import os
import logging
from imagekitio import ImageKit
from IPython.display import Image, display

logger = logging.getLogger(__name__)

client = ImageKit(
    private_key=os.environ.get("IMAGEKIT_PRIVATE_KEY"),
)


def build_url(
    url_endpoint: str,
    src: str,
    transformation=None,
) -> str:
    if isinstance(transformation, dict):
        transformation = [transformation]
    url = client.helper.build_url(
        url_endpoint=url_endpoint,
        src=src,
        transformation=transformation,
    )
    # print(url)
    display(Image(url=url))
    return url

# %% [markdown]
# # 1. Basic image overlay (media library image)

# %%
params = {
    "image_path": "logo.png",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo.png,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo.png,l-end'

# %%
params = {"image_path": "logo.png", "encoded": True}

transforms = ImageOverlay(**params).to_overlay_dict()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'logo.png', 'encoding': 'base64'}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,ie-bG9nby5wbmc%3D,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,ie-bG9nby5wbmc%3D,l-end'

# %% [markdown]
# ## 3. Overlay image from a folder

# %%
params = {
    "image_path": "/mcp/chup_chap_lelo.png_updatedAt=1759928802923",
}

transforms = ImageOverlay(**params).to_overlay_dict()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/2pej2semh",
    src="/mcp/final/WTHCTMR5060_LS_1__6__qPjCw08y9_PytlSkWQQ.jpg",
    transformation=transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': '/mcp/chup_chap_lelo.png_updatedAt=1759928802923', 'encoding': 'plain'}}
# <img src="https://ik.imagekit.io/2pej2semh/mcp/final/WTHCTMR5060_LS_1__6__qPjCw08y9_PytlSkWQQ.jpg?tr=l-image,i-mcp@@chup_chap_lelo.png_updatedAt=1759928802923,l-end"/>
# 'https://ik.imagekit.io/2pej2semh/mcp/final/WTHCTMR5060_LS_1__6__qPjCw08y9_PytlSkWQQ.jpg?tr=l-image,i-mcp@@chup_chap_lelo.png_updatedAt=1759928802923,l-end'

# %% [markdown]
# ## 4. Position overlay using lx

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_x": 35,
}


transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-35,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-35,l-end'

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_x": -35,
}
transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-N35,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-N35,l-end'

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_x": "bw_mul_0.2",
}


transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-bw_mul_0.2,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-bw_mul_0.2,l-end'

# %% [markdown]
# ## 5. Position overlay using both lx and ly

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_x": "bw_mul_0.2",
    "layer_y": "bh_mul_0.4",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-bw_mul_0.2,ly-bh_mul_0.4,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-bw_mul_0.2,ly-bh_mul_0.4,l-end'

# %% [markdown]
# ## 6. Center horizontally, 20% from top

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_y": "bh_mul_0.2",
    "layer_x": "bw_div_2_sub_iw_div_2",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-bw_div_2_sub_iw_div_2,ly-bh_mul_0.2,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lx-bw_div_2_sub_iw_div_2,ly-bh_mul_0.2,l-end'

# %% [markdown]
# ## 7. Resize overlay + pad resize + background

# %%
params = {
    "image_path": "women-dress.jpeg",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": "yellow",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,w-400,h-400,cm-pad_resize,bg-yellow,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,w-400,h-400,cm-pad_resize,bg-yellow,l-end'

# %% [markdown]
# ## 9. Resize overlay relative to base image

# %%
params = {
    "image_path": "women-dress.jpeg",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": "yellow",
    "effects": {"grayscale": True},
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,w-400,h-400,cm-pad_resize,bg-yellow,e-grayscale,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,w-400,h-400,cm-pad_resize,bg-yellow,e-grayscale,l-end'

# %%
# Full height, half width, top-left

params = {
    "image_path": "women-dress.jpeg",
    "height": "bh",
    "width": "iw_div_2",
    "layer_x": 0,
    "layer_y": 0,
    "background": "yellow",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,lx-0,ly-0,w-iw_div_2,h-bh,bg-yellow,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,lx-0,ly-0,w-iw_div_2,h-bh,bg-yellow,l-end'

# %% [markdown]
# ## 11. Nested layer

# %%
params = {
    "image_path": "women-dress.jpeg",
    "height": "bh_div_2",
    "width": "bw_div_2",
    "crop_mode": "pad_resize",
    "background": "yellow",
    "child": {
        # child layer do not allow arithmetic expressions for
        # height and width
        "image_path": "women-dress.jpeg",
        # "h": 100,
        "height": "200",
        "width": "200",
        # "w": 200,
        "crop_mode": "pad_resize",
        "background": "red",
    },
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,w-bw_div_2,h-bh_div_2,cm-pad_resize,bg-yellow,l-image,i-women-dress.jpeg,w-200,h-200,cm-pad_resize,bg-red,l-end,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,w-bw_div_2,h-bh_div_2,cm-pad_resize,bg-yellow,l-image,i-women-dress.jpeg,w-200,h-200,cm-pad_resize,bg-red,l-end,l-end'

# %% [markdown]
# ## 12. Nested overlays with relative focus (lfo)

# %%
params = {
    "image_path": "women-dress.jpeg",
    "height": 400,
    "effects": {
        "border": {"border_width": 10, "color": "red"},
    },
    "layer_focus": "bottom_left",
    "child": {
        "image_path": "logo-white_SJwqB4Nfe.png",
        "width": 150,
        "layer_focus": "top_right",
    },
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,lfo-bottom_left,h-400,b-10_red,l-image,i-logo-white_SJwqB4Nfe.png,lfo-top_right,w-150,l-end,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-women-dress.jpeg,lfo-bottom_left,h-400,b-10_red,l-image,i-logo-white_SJwqB4Nfe.png,lfo-top_right,w-150,l-end,l-end'

# %%
# /?tr=l-image,i-radialize.jpeg,lm-displace,y-100,l-end
params = {
    "image_path": "radialize.jpeg",
    "encoded": False,
    "layer_mode": "displace",
    "y": 100,
}

transforms = ImageOverlay(**params).to_overlay_dict()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/ikmedia",
    src="docs_images/features/image-transformations/car.jpeg",
    transformation=transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'radialize.jpeg', 'encoding': 'plain', 'transformation': [{'y': '100', 'lm': 'displace'}]}}
# <img src="https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg?tr=l-image,i-radialize.jpeg,y-100,lm-displace,l-end"/>
# 'https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg?tr=l-image,i-radialize.jpeg,y-100,lm-displace,l-end'

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_mode": "multiply",
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'logo-white_SJwqB4Nfe.png', 'encoding': 'plain', 'transformation': [{'lm': 'multiply'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lm-multiply,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lm-multiply,l-end'

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_mode": "cutout",
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'logo-white_SJwqB4Nfe.png', 'encoding': 'plain', 'transformation': [{'lm': 'cutout'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lm-cutout,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lm-cutout,l-end:bg-indigo'

# %%
params = {
    "image_path": "logo-white_SJwqB4Nfe.png",
    "layer_mode": "cutter",
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'logo-white_SJwqB4Nfe.png', 'encoding': 'plain', 'transformation': [{'lm': 'cutter'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lm-cutter,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-logo-white_SJwqB4Nfe.png,lm-cutter,l-end:bg-indigo'

# %% [markdown]
# # Solid Overlay

# %%
# simple examples of solid overlay
params = {
    "image_path": "ik_canvas",
    "background": "FF0000",
    "width": 300,
    "height": 100,
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'ik_canvas', 'encoding': 'plain', 'transformation': [{'width': '300', 'height': '100', 'background': 'FF0000'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,w-300,h-100,bg-FF0000,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,w-300,h-100,bg-FF0000,l-end:bg-indigo'

# %%
# simple examples of solid overlay with position control
params = {
    "image_path": "ik_canvas",
    "background": "FF0000",
    "width": 300,
    "height": 100,
    "layer_x": 35,
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'ik_canvas', 'encoding': 'plain', 'position': {'x': '35'}, 'transformation': [{'width': '300', 'height': '100', 'background': 'FF0000'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,lx-35,w-300,h-100,bg-FF0000,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,lx-35,w-300,h-100,bg-FF0000,l-end:bg-indigo'

# %%
# simple examples of solid overlay with position control with negative x
params = {
    "image_path": "ik_canvas",
    "background": "FF0000",
    "width": 300,
    "height": 100,
    "layer_x": -35,
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'ik_canvas', 'encoding': 'plain', 'position': {'x': 'N35'}, 'transformation': [{'width': '300', 'height': '100', 'background': 'FF0000'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,lx-N35,w-300,h-100,bg-FF0000,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,lx-N35,w-300,h-100,bg-FF0000,l-end:bg-indigo'

# %%
# simple examples of solid overlay with position control with 80% of width
params = {
    "image_path": "ik_canvas",
    "background": "red",
    "width": 300,
    "height": 100,
    "layer_y": "bw_mul_0.8",
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'ik_canvas', 'encoding': 'plain', 'position': {'y': 'bw_mul_0.8'}, 'transformation': [{'width': '300', 'height': '100', 'background': 'red'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,ly-bw_mul_0.8,w-300,h-100,bg-red,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,ly-bw_mul_0.8,w-300,h-100,bg-red,l-end:bg-indigo'

# %%
# gradient effect on solid overlay
params = {
    "image_path": "ik_canvas",
    "background": "FF0000",
    "width": 300,
    "height": 100,
    "effects": {
        "gradient": {
            "linear_direction": "top_left",
            "from_color": "lightskyblue",
            "to_color": "mintcream",
            "stop_point": 1,
        }
    },
}

transforms = ImageOverlay(**params).to_overlay_dict()
final_transforms = [transforms, {"bg": "indigo"}]
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=final_transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'ik_canvas', 'encoding': 'plain', 'transformation': [{'width': '300', 'height': '100', 'background': 'FF0000', 'e-gradient': 'ld-top_left_from-lightskyblue_to-mintcream_sp-1'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,w-300,h-100,bg-FF0000,e-gradient-ld-top_left_from-lightskyblue_to-mintcream_sp-1,l-end:bg-indigo"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,w-300,h-100,bg-FF0000,e-gradient-ld-top_left_from-lightskyblue_to-mintcream_sp-1,l-end:bg-indigo'

# %%
# round solid overlay
params = {
    "image_path": "ik_canvas",
    "background": "red",
    "width": 200,
    "height": 200,
    "effects": {"radius": "max"},
}

transforms = ImageOverlay(**params).to_overlay_dict()
print(transforms)
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    # transformation=transforms,
    transformation=transforms,
)
# Out:
# {'overlay': {'type': 'image', 'input': 'ik_canvas', 'encoding': 'plain', 'transformation': [{'width': '200', 'height': '200', 'background': 'red', 'r': 'max'}]}}
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,w-200,h-200,bg-red,r-max,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-ik_canvas,w-200,h-200,bg-red,r-max,l-end'

# %% [markdown]
# # Background

# %%
# Background with solid color with image overlay
params = {
    "image_path": "sample_image.jpg",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": "yellow",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-yellow,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-yellow,l-end'

# %%
# Background with solid color with transparent background
params = {
    "image_path": "lipstick_1M.png",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": "yellow",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-lipstick_1M.png,w-400,h-400,cm-pad_resize,bg-yellow,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-lipstick_1M.png,w-400,h-400,cm-pad_resize,bg-yellow,l-end'

# %%
# Background with blurred background
params = {
    "image_path": "sample_image.jpg",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": {
        "blur_intensity": 50,
        "brightness": 50,
    },
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-blurred_50_50,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-blurred_50_50,l-end'

# %%
# Background with dominant background
params = {
    "image_path": "sample_image.jpg",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": "dominant",
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-dominant,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-dominant,l-end'

# %%
# Image layer with gradient background
params = {
    "image_path": "sample_image.jpg",
    "height": 400,
    "width": 400,
    "crop_mode": "pad_resize",
    "background": {
        "mode": "dominant",
        "pallete_size": 2,
    },
}

transforms = ImageOverlay(**params).to_overlay_dict()
build_url(
    url_endpoint="https://ik.imagekit.io/demo",
    src="medium_cafe_B1iTdD0C.jpg",
    transformation=transforms,
)
# Out:
# <img src="https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-gradient_dominant_2,l-end"/>
# 'https://ik.imagekit.io/demo/medium_cafe_B1iTdD0C.jpg?tr=l-image,i-sample_image.jpg,w-400,h-400,cm-pad_resize,bg-gradient_dominant_2,l-end'
