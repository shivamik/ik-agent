# %%
# %cd ..
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
from src.agent import agent
# Out:
# WARNING | typesense | Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.
# INFO | src.config | Created Typesense conversation model.
# /Users/shivamkaushik/Code/ik-agent/.venv/lib/python3.12/site-packages/pydantic/main.py:1809: UserWarning: Field name "schema" in "Create_custom_metadata_fields_toolTool" shadows an attribute in parent "BaseModel"
#   return meta(
# /Users/shivamkaushik/Code/ik-agent/.venv/lib/python3.12/site-packages/pydantic/main.py:1809: UserWarning: Field name "schema" in "Update_custom_metadata_fields_toolTool" shadows an attribute in parent "BaseModel"
#   return meta(
# <Logger transforms.ai_transforms (DEBUG)>

# %%
prompt = """
I have this file https://ik.imagekit.io/2pej2semh/Actual%20Image.png. Add a ai drop shadow to the image.
"""
agent(prompt)
# Out:
# INFO | strands.telemetry.metrics | Creating Strands MetricsClient
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Resolving transform for query: Add an AI-generated realistic soft drop shadow around the subject with natural lighting and keep original size and background transparent if possible
# Tool #1: transformation-builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Classification result: {'methods': ['ai_transform'], 'unresolved_intent': ''}
# INFO | transform_builder | Filtered 9 metadata entries using methods=['ai_transform']
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Structured plan steps: 2
# INFO | transform_builder | Structured plan steps: [{'method': 'ai_transform', 'params': {'ai_remove_background_external': True}}, {'method': 'ai_transform', 'params': {'ai_drop_shadow': True}}]
# INFO | transform_builder | [{'method': 'ai_transform', 'params': {'ai_remove_background_external': True}}, {'method': 'ai_transform', 'params': {'ai_drop_shadow': True}}], {}
# INFO | transform_builder | Applying structured plan with 2 step(s) and doc_params=False
# INFO | transform_builder | Built 2 transformation(s)
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s your image with an AI drop shadow applied:
#
# https://ik.imagekit.io/2pej2semh/Actual%20Image.png?tr=e-removedotbg:e-dropshadow
#
# This URL keeps the original size, removes the background with AI, and adds a realistic drop shadow around the subject. You can use this URL directly in your app or site.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Here’s your image with an AI drop shadow applied:\n\nhttps://ik.imagekit.io/2pej2semh/Actual%20Image.png?tr=e-removedotbg:e-dropshadow\n\nThis URL keeps the original size, removes the background with AI, and adds a realistic drop shadow around the subject. You can use this URL directly in your app or site.'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={'transformation-builder': ToolMetrics(tool={'toolUseId': 'call_p6ld6dX1cq5bVRv0wPvg3SjL', 'name': 'transformation-builder', 'input': {'query': 'Add an AI-generated realistic soft drop shadow around the subject with natural lighting and keep original size and background transparent if possible', 'src': 'https://ik.imagekit.io/2pej2semh/Actual%20Image.png'}}, call_count=1, success_count=1, error_count=0, total_time=3.8536629676818848)}, cycle_durations=[1.4744503498077393], traces=[<strands.telemetry.metrics.Trace object at 0x10fb71250>, <strands.telemetry.metrics.Trace object at 0x10fb70b60>], accumulated_usage={'inputTokens': 2946, 'outputTokens': 148, 'totalTokens': 3094}, accumulated_metrics={'latencyMs': 0}), state={}, interrupts=None, structured_output=None)

# %%
prompt = """
Generate an AI image of a dog. Use upscale it. Remove its background. 
"""
agent(prompt)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | imagekitio._base_client | Retrying request to /v1/files in 0.395852 seconds
# Tool #6: imagekit-generate-image
# INFO | httpx | HTTP Request: GET https://api.imagekit.io/v1/files?limit=1&type=file "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Resolving transform for query: Upscale the image using AI and then remove the background using AI
# INFO | openai._base_client | Retrying request to /chat/completions in 0.427173 seconds
# Tool #7: transformation-builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Classification result: {'methods': ['ai_transform'], 'unresolved_intent': ''}
# INFO | transform_builder | Filtered 9 metadata entries using methods=['ai_transform']
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Structured plan steps: 2
# INFO | transform_builder | Structured plan steps: [{'method': 'ai_transform', 'params': {'ai_upscale': True}}, {'method': 'ai_transform', 'params': {'ai_remove_background': True}}]
# INFO | transform_builder | [{'method': 'ai_transform', 'params': {'ai_upscale': True}}, {'method': 'ai_transform', 'params': {'ai_remove_background': True}}], {}
# INFO | transform_builder | Applying structured plan with 2 step(s) and doc_params=False
# INFO | transform_builder | Built 2 transformation(s)
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s your AI-generated dog image, upscaled with AI and then background removed:
#
# https://ik.imagekit.io/2pej2semh/ik-genimg-prompt-a%20realistic%20portrait%20of%20a%20dog%2C%20facing%20forward%2C%20well%20lit%2C%20high%20resolution/gen-images/dog-upscale-bgremove.png?tr=e-upscale:e-bgremove
#
# You can use this URL directly to load the final processed image.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Here’s your AI-generated dog image, upscaled with AI and then background removed:\n\nhttps://ik.imagekit.io/2pej2semh/ik-genimg-prompt-a%20realistic%20portrait%20of%20a%20dog%2C%20facing%20forward%2C%20well%20lit%2C%20high%20resolution/gen-images/dog-upscale-bgremove.png?tr=e-upscale:e-bgremove\n\nYou can use this URL directly to load the final processed image.'}]}, metrics=EventLoopMetrics(cycle_count=11, tool_metrics={'transformation-builder': ToolMetrics(tool={'toolUseId': 'call_DDxvhEh2bekihDiFcORFHgYR', 'name': 'transformation-builder', 'input': {'query': 'Upscale the image using AI and then remove the background using AI', 'src': 'https://ik.imagekit.io/2pej2semh/ik-genimg-prompt-a%20realistic%20portrait%20of%20a%20dog%2C%20facing%20forward%2C%20well%20lit%2C%20high%20resolution/gen-images/dog-upscale-bgremove.png'}}, call_count=4, success_count=4, error_count=0, total_time=15.421797752380371), 'imagekit-generate-image': ToolMetrics(tool={'toolUseId': 'call_tfKmzCnFhCUp3Q1jmWQulMim', 'name': 'imagekit-generate-image', 'input': {'prompt': 'a realistic portrait of a dog, facing forward, well lit, high resolution', 'image_path': 'gen-images/dog-upscale-bgremove.png'}}, call_count=3, success_count=3, error_count=0, total_time=6.821966886520386)}, cycle_durations=[1.4744503498077393, 1.7061140537261963, 2.118773937225342, 1.8914141654968262], traces=[<strands.telemetry.metrics.Trace object at 0x10fb71250>, <strands.telemetry.metrics.Trace object at 0x10fb70b60>, <strands.telemetry.metrics.Trace object at 0x10f7615e0>, <strands.telemetry.metrics.Trace object at 0x10fb34fe0>, <strands.telemetry.metrics.Trace object at 0x10fb70710>, <strands.telemetry.metrics.Trace object at 0x110130620>, <strands.telemetry.metrics.Trace object at 0x1100d3110>, <strands.telemetry.metrics.Trace object at 0x10ff13770>, <strands.telemetry.metrics.Trace object at 0x1101a0530>, <strands.telemetry.metrics.Trace object at 0x11017da30>, <strands.telemetry.metrics.Trace object at 0x11017c6e0>], accumulated_usage={'inputTokens': 23271, 'outputTokens': 997, 'totalTokens': 24268}, accumulated_metrics={'latencyMs': 0}), state={}, interrupts=None, structured_output=None)

# %%
prompt = """
Resize an image `https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?updatedAt=1767598239485` to 300x300
"""
agent(prompt)
# Out:
# INFO | strands.telemetry.metrics | Creating Strands MetricsClient
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Resolving transform for query: Resize the image to 300x300 pixels, keeping aspect ratio if needed
# Tool #1: transformation-builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Classification result: {'methods': ['resize_and_crop'], 'unresolved_intent': ''}
# INFO | transform_builder | Filtered 12 metadata entries using methods=['resize_and_crop']
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Structured plan steps: 1
# INFO | transform_builder | Structured plan steps: [{'method': 'resize_and_crop', 'params': {'width': 300, 'height': 300, 'crop': 'maintain_ratio'}}]
# INFO | transform_builder | [{'method': 'resize_and_crop', 'params': {'width': 300, 'height': 300, 'crop': 'maintain_ratio'}}], {}
# INFO | transform_builder | Applying structured plan with 1 step(s) and doc_params=False
# INFO | transform_builder | Built 1 transformation(s)
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here is the resized image URL (300×300):
#
# https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?tr=w-300,h-300,c-maintain_ratio
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Here is the resized image URL (300×300):\n\nhttps://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?tr=w-300,h-300,c-maintain_ratio'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={'transformation-builder': ToolMetrics(tool={'toolUseId': 'call_ZaegP3blfqRZLLwNY4kBFv4u', 'name': 'transformation-builder', 'input': {'query': 'Resize the image to 300x300 pixels, keeping aspect ratio if needed', 'src': 'https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?updatedAt=1767598239485'}}, call_count=1, success_count=1, error_count=0, total_time=2.984498977661133)}, cycle_durations=[1.3755691051483154], traces=[<strands.telemetry.metrics.Trace object at 0x11a4713d0>, <strands.telemetry.metrics.Trace object at 0x11d0d7b30>], accumulated_usage={'inputTokens': 2820, 'outputTokens': 136, 'totalTokens': 2956}, accumulated_metrics={'latencyMs': 0}), state={}, interrupts=None, structured_output=None)

# %%
prompt = """
Do the following transformation on the image `https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?updatedAt=1767598239485`
Crop around the car in the image and then resize it to 200x400. add padding if necessary. Padding color should be light gray.
"""
agent(prompt)
# Out:
# INFO | strands.telemetry.metrics | Creating Strands MetricsClient
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Resolving transform for query: Crop around the car in the image and then resize it to 200x400 pixels. Maintain aspect ratio, add padding if necessary so the final image is exactly 200x400, and use a light gray background color for the padding.
# Tool #1: transformation-builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Classification result: {'methods': ['resize_and_crop'], 'unresolved_intent': 'search query: how to specify padding background color in ImageKit resize_and_crop transformation'}
# INFO | transform_builder | Filtered 12 metadata entries using methods=['resize_and_crop']
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Structured plan steps: 1
# INFO | transform_builder | Structured plan steps: [{'method': 'resize_and_crop', 'params': {'width': 200, 'height': 400, 'crop_mode': 'pad_extract', 'focus': 'car', 'background': 'F3F3F3'}}]
# INFO | transform_builder | Falling back to docs search (unresolved=True, structured=True)
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transform_builder | Extracted 2 doc param(s)
# INFO | transform_builder | [{'method': 'resize_and_crop', 'params': {'width': 200, 'height': 400, 'crop_mode': 'pad_extract', 'focus': 'car', 'background': 'F3F3F3'}}], {'params': {'cm': 'pad_resize', 'bg': 'F3F3F3'}}
# INFO | transform_builder | Applying structured plan with 1 step(s) and doc_params=True
# INFO | transform_builder | Built 2 transformation(s)
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformed image URL with the requested edits applied:
#
# `https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?tr=w-200,h-400,c-maintain_ratio,cm-pad_extract,fo-car,bg-F3F3F3:cm-pad_resize,bg-F3F3F3`
#
# What it does:
# - Crops around the car as the focus.
# - Resizes while maintaining aspect ratio.
# - Pads as needed to exactly 200x400.
# - Uses light gray (`#F3F3F3`) as the padding color.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Here’s the transformed image URL with the requested edits applied:\n\n`https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?tr=w-200,h-400,c-maintain_ratio,cm-pad_extract,fo-car,bg-F3F3F3:cm-pad_resize,bg-F3F3F3`\n\nWhat it does:\n- Crops around the car as the focus.\n- Resizes while maintaining aspect ratio.\n- Pads as needed to exactly 200x400.\n- Uses light gray (`#F3F3F3`) as the padding color.'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={'transformation-builder': ToolMetrics(tool={'toolUseId': 'call_U3OOgZRsyU9bd0PNuSb2fTRt', 'name': 'transformation-builder', 'input': {'query': 'Crop around the car in the image and then resize it to 200x400 pixels. Maintain aspect ratio, add padding if necessary so the final image is exactly 200x400, and use a light gray background color for the padding.', 'src': 'https://ik.imagekit.io/2pej2semh/gemini_test_image_5454_3vQfksAeO.png?updatedAt=1767598239485'}}, call_count=1, success_count=1, error_count=0, total_time=9.008831977844238)}, cycle_durations=[2.399906873703003], traces=[<strands.telemetry.metrics.Trace object at 0x11c2ecb60>, <strands.telemetry.metrics.Trace object at 0x11c2ec950>], accumulated_usage={'inputTokens': 2933, 'outputTokens': 249, 'totalTokens': 3182}, accumulated_metrics={'latencyMs': 0}), state={}, interrupts=None, structured_output=None)

# %%
from src.modules.ik_transforms.transformation_builder import build_final_transformations

# structured_plan = [
#     {
#         "method": "resize_and_crop",
#         "params": {
#             "width": 200,
#             "height": 400,
#             "crop_mode": "pad_extract",
#             "focus": "car",
#             "background": "F3F3F3",
#         },
#     }
# ]
# doc_params = {"params": {"bg": "F3F3F3"}}
structured_plan = []
doc_params = {'params': {'e-removedotbg': '', 'e-dropshadow': ''}}

transformations = build_final_transformations(
    structured_plan=structured_plan,
    doc_params=doc_params,
)
# Out:
# INFO | transform_builder | Built 0 transformation(s)

# %%
import pandas as pd

df = pd.read_csv('static/ik_transforms.csv')
df
# Out:
#                       parameter_name  ...      method_name
# 0                              width  ...  resize_and_crop
# 1                             height  ...  resize_and_crop
# 2                       Aspect Ratio  ...  resize_and_crop
# 3                          Crop Mode  ...  resize_and_crop
# 4                               Crop  ...  resize_and_crop
# 5                       Focus Custom  ...  resize_and_crop
# 6            Focus Auto - Smart Crop  ...  resize_and_crop
# 7            Focus Face - Smart Crop  ...  resize_and_crop
# 8         Focus Objects - Smart Crop  ...  resize_and_crop
# 9                               Zoom  ...  resize_and_crop
# 10          x position of cm_extract  ...  resize_and_crop
# 11                               dpr  ...  resize_and_crop
# 12  Remove dot bg Background removal  ...     ai_transform
# 13       Imagekit background removal  ...     ai_transform
# 14                    AI Drop Shadow  ...     ai_transform
# 15              AI Change Background  ...     ai_transform
# 16                           AI Edit  ...     ai_transform
# 17                   Generative fill  ...     ai_transform
# 18                          Retouch   ...     ai_transform
# 19                         AI Upcale  ...     ai_transform
# 20           AI Generative Variation  ...     ai_transform
#
# [21 rows x 10 columns]

# %%
from src.tools.assets.list_assets import list_assets

# %%
files = await list_assets(
    type='file', 
    limit=2,
    filter_spec=[{
        'url': 'url'
    }])
# Out:
# INFO | httpx | HTTP Request: GET https://api.imagekit.io/v1/files?limit=2&type=file "HTTP/1.1 200 OK"

# %%
files
# Out:
# [{'url': 'https://ik.imagekit.io/2pej2semh/default-image.jpg?updatedAt=1702969543773'},
#  {'url': 'https://ik.imagekit.io/2pej2semh/e_commerce_dataset/fashion_accessories/10.jpeg?updatedAt=1707724068839'}]
