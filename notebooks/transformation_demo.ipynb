# %%
# %cd ..
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
from src.agent import agent

from IPython.display import display, Markdown

def display_agent_message(agent_message: dict):
    content = agent_message.get("content", [])
    text_blocks = [
        block["text"] for block in content if block.get("text")
    ]
    markdown = "\n\n".join(text_blocks)
    display(Markdown(markdown))
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.
# /Users/shivamkaushik/Code/ik-agent/.venv/lib/python3.12/site-packages/pydantic/main.py:1809: UserWarning: Field name "schema" in "Create_custom_metadata_fields_toolTool" shadows an attribute in parent "BaseModel"
#   return meta(
# /Users/shivamkaushik/Code/ik-agent/.venv/lib/python3.12/site-packages/pydantic/main.py:1809: UserWarning: Field name "schema" in "Update_custom_metadata_fields_toolTool" shadows an attribute in parent "BaseModel"
#   return meta(

# %% [markdown]
# # Resize and Crop

# %% [markdown]
# ## Width

# %% [markdown]
# 200px Wide

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make it 300px wide
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Tool #1: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,c-maintain_ratio
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformed URL with the image resized to 300px wide while keeping aspect ratio:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,c-maintain_ratio
# Here’s the transformed URL with the image resized to 300px wide while keeping aspect ratio:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,c-maintain_ratio

# %% [markdown]
# 40% of original image

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make it 40% of original image
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.480104 seconds
# Tool #2: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-0.4,c-maintain_ratio
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformed URL that resizes the image to 40% of its original size while maintaining aspect ratio:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-0.4,c-maintain_ratio
# Here’s the transformed URL that resizes the image to 40% of its original size while maintaining aspect ratio:
# ...

# %% [markdown]
# Half Width

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width to be half of the original image height
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.449042 seconds
# Tool #2: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-ih_div_2,c-maintain_ratio
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL where the image width is set to half of the original image height, keeping aspect ratio:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-ih_div_2,c-maintain_ratio
# ...

# %% [markdown]
# ## Height

# %% [markdown]
# 200px Height

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the height to be 200px
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.376239 seconds
# Tool #3: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=h-200,c-maintain_ratio
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL to resize the image so its height is 200px while keeping the aspect ratio:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=h-200,c-maintain_ratio
# Here’s the transformation URL to resize the image so its height is 200px while keeping the aspect ratio:
#
# ...

# %% [markdown]
# ## Aspect Ratio

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width to be 400px and aspect ratio to be 4:3
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Tool #1: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transforms.resize_and_crop | 4-3
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=ar-4_3,c-maintain_ratio,fo-auto
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here is the transformation URL with a 4:3 aspect ratio applied:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=ar-4_3,c-maintain_ratio,fo-auto
#
# This sets:
# - `ar-4_3` → aspect ratio 4:3
# - `c-maintain_ratio` → keeps the image’s proportions while fitting it into 4:3
# ...

# %% [markdown]
# Width 400px and Aspect ratio 2:1

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width to be 400px and aspect ratio to be double
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.476652 seconds
# Tool #3: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | transforms.resize_and_crop | Validating ResizeAndCrop params: {}
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-400,h-800,c-maintain_ratio
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL for that requirement:
#
# https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-400,h-800,c-maintain_ratio
#
# This sets:
# - Width = 400px
# ...

# %% [markdown]
# # Crop and crop mode

# %% [markdown]
# ## cm pad Resize

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width 400px and height 200px
Add resizing. Do not crop and add background color F3F3F3
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.408033 seconds
# Tool #8: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-400,h-200,c-maintain_ratio,cm-pad_resize,bg-F3F3F3
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL that resizes the image to 400×200px, does not crop, and pads with background color `#F3F3F3`:
#
# `https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-400,h-200,c-maintain_ratio,cm-pad_resize,bg-F3F3F3`
# ...

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width 400px and height 200px
Add resizing. Do not crop and add background color F3F3F3. Only add padding to right.
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.444624 seconds
# Tool #9: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-400,h-200,c-maintain_ratio,cm-pad_resize,fo-left,bg-F3F3F3
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL that resizes the image to 400×200px, does not crop, adds padding, and pushes padding only to the right side using left focus (`fo-left`):
#
# ...

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width 100px and height 200px
Add resizing. Do not crop and add background color F3F3F3. Only add padding to bottom.
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.378201 seconds
# Tool #11: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-100,h-200,c-maintain_ratio,cm-pad_resize,fo-top,bg-F3F3F3
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL that resizes the image to 100×200px, does not crop, and adds padding only to the bottom (using top focus) with background color `#F3F3F3`:
#
# ...

# %% [markdown]
# ## c-force

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width 300px and height 200px.
Force it to be 300x200
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.451562 seconds
# Tool #15: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,h-200,c-force
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Use this transformation URL to force the image to exactly 300×200px (aspect ratio will be changed/stretched as needed):
#
# `https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,h-200,c-force`
# ...

# %% [markdown]
# # c-at_max_enlarge

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width 300px and height 200px.
I want to preserve aspect ratio. Atleast match one dimension, no padding
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.490894 seconds
# Tool #20: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,h-200,c-at_max_enlarge
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL that preserves aspect ratio, avoids padding, and ensures at least one dimension reaches the requested size (300×200):
#
# `https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-300,h-200,c-at_max_enlarge`
# ...

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg

Build a transformation to resize it to make the width 850px and height 1000px.
I want to preserve aspect ratio. Atleast match one dimension
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.425377 seconds
# Tool #18: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-850,h-1000,c-at_max_enlarge
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s a transformation URL that preserves aspect ratio and resizes the image so it fits within 850×1000, with at least one dimension matching exactly (width or height):
#
# `https://ik.imagekit.io/ikmedia/docs_images/examples/example_food_3.jpg?tr=w-850,h-1000,c-at_max_enlarge`
# ...

# %% [markdown]
# # Focus - fo

# %% [markdown]
# ## Auto smart cropping

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/Smart_crop_example.jpg

Build a transformation to resize it to make the width w-200 and height 300px. But I want auto focus.
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.488594 seconds
# Tool #21: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/Smart_crop_example.jpg?tr=w-200,h-300,c-maintain_ratio,fo-auto
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL that resizes the image to 200×300px with auto focus (smart focus on the important subject):
#
# `https://ik.imagekit.io/ikmedia/docs_images/examples/Smart_crop_example.jpg?tr=w-200,h-300,c-maintain_ratio,fo-auto`
# ...

# %% [markdown]
# ## Face Cropping fo-face

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/examples/example_portrait_1.jpg

Build a transformation to resize it to make the width w-200 and height 300px. Trim aroung face
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.393018 seconds
# Tool #22: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/examples/example_portrait_1.jpg?tr=w-200,h-300,c-maintain_ratio,fo-face
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s the transformation URL that resizes the portrait to 200×300px and trims around the face:
#
# `https://ik.imagekit.io/ikmedia/docs_images/examples/example_portrait_1.jpg?tr=w-200,h-300,c-maintain_ratio,fo-face`
# ...

# %% [markdown]
# ## Object Aware Cropping - (fo-object name)

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg

Build a transformation to tightly crop around car
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.485982 seconds
# Tool #23: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG | tools.transformation_builder | Built transformation URL: https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg?tr=c-maintain_ratio,fo-car
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here’s a transformation URL that tightly crops around the car by focusing on it:
#
# `https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg?tr=c-maintain_ratio,fo-car`
# Here’s a transformation URL that tightly crops around the car by focusing on it:
#
# ...

# %% [markdown]
# Tight crop with aspect ratio

# %%
prompt = """
I have this file https://ik.imagekit.io/ikmedia/docs_images/features/image-transformations/car.jpeg

Build a transformation to tightly crop around car and aspect_ratio 2:1
"""
agent_results = agent(prompt)

display_agent_message(agent_results.message)
# Out:
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | openai._base_client | Retrying request to /chat/completions in 0.391687 seconds
# Tool #26: transformation_builder
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# I don’t have that information in ImageKit documentation.
#
# The transformation builder tool returns a validation error specifically for the `aspect_ratio` value when trying to set it to “2:1” (it interprets it as `2-1` and marks it invalid), and I’m required not to guess or infer unsupported syntax. Because of that, I can’t provide a reliable, tool-backed transformation URL that both:
#
# - tightly crops around the car, and
# - sets `aspect_ratio` to 2:1,
#
# ...

# %%
from
