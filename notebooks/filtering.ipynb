# %%
# %cd ..
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
from src.utils.filter_responses import TOOL_RESPONSE_MAP

# %%
print(TOOL_RESPONSE_MAP)
# Out:
# {'list_assets': {'type': typing.List[typing.Union[imagekitio.types.file.File, imagekitio.types.folder.Folder]], 'keys': {'file_path', 'tags', 'name', 'mime', 'custom_metadata', 'height', 'type', 'created_at', 'size', 'url', 'is_private_file', 'version_info', 'description', 'file_type', 'is_published', 'width', 'folder_path', 'thumbnail', 'updated_at', 'selected_fields_schema', 'custom_coordinates', 'folder_id', 'file_id', 'has_alpha', 'ai_tags'}}, 'create_accounts_origins': {'type': typing.Union[imagekitio.types.accounts.origin_response.S3, imagekitio.types.accounts.origin_response.S3Compatible, imagekitio.types.accounts.origin_response.CloudinaryBackup, imagekitio.types.accounts.origin_response.WebFolder, imagekitio.types.accounts.origin_response.WebProxy, imagekitio.types.accounts.origin_response.Gcs, imagekitio.types.accounts.origin_response.AzureBlob, imagekitio.types.accounts.origin_response.AkeneoPim], 'keys': {'account_name', 's3_force_path_style', 'include_canonical_header', 
# ...
