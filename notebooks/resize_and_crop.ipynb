# %%
# %cd ..
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
from src.modules.ik_transforms.transforms.resize_n_crop import ResizeAndCrop
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.

# %%
ResizeAndCrop(
    aspect_ratio="2-1"
).to_transform_dict()
# Out:
# {'aspect_ratio': '2_1', 'crop': 'maintain_ratio'}
