# %%
# %cd ..
# Out:
# /Users/shivamkaushik/Code/ik-agent

# %%
from src.modules.ik_transforms.transforms.ai_transforms import AITransforms
from src.clients import CLIENT

# %%
res = AITransforms().ai_transform(
    # ai_remove_background=True,
    ai_drop_shadow=True,
    ai_upscale=True,
    ai_bg_genfill=True,
    height=800,
    width=600,
)
res
# Out:
# [{'bg': 'genfill', 'h': 800, 'w': 600, 'cm': 'pad_resize'},
#  {'e-bgremove': True},
#  {'e-dropshadow': True, 'az': 215, 'el': 45, 'st': 60},
#  {'e-upscale': True}]

# %%
await CLIENT.helper.build_url(
    src="https://ik.imagekit.io/your_imagekit_id/default-image.jpg",
    transformation=res,
)
# Out:
# 'https://ik.imagekit.io/your_imagekit_id/default-image.jpg?tr=bg-genfill,h-800,w-600,cm-pad_resize:e-bgremove:e-dropshadow,az-215,el-45,st-60:e-upscale'
